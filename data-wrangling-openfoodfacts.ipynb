# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa 

from IPython.display import clear_output
from sqlalchemy import Table, Column, Integer, String, VARCHAR

filename = 'en.openfoodfacts.org.products.csv'
df = pd.read_csv(filename, sep='\t', engine='python', skiprows=range(2, 200), nrows=10000)
filename_sample = 'en.openfoodfacts.org.products_sample.csv'
df.to_csv(filename_sample,sep='~',index=True)
# df.to_csv(filename_sample,sep='\t',index=True)

# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa 

from IPython.display import clear_output
from sqlalchemy import Table, Column, Integer, String, VARCHAR

filename = 'en.openfoodfacts.org.products.csv'
df = pd.read_csv(filename, sep='\t', engine='python', skiprows=range(2, 200), nrows=10000)
filename = 'en.openfoodfacts.org.products_sample.csv'
# for col_name in df.columns: 
#     print(col_name)
# df.keys()


engine = sa.create_engine(
    'postgresql://postgres:password@localhost:5404/graphqldb')
    # 'postgresql://postgres:example@localhost:5432/strapi')
postgreSQLConnection = engine.connect()

# df = pd.read_json(r'RAW_recipes-arrays-formatted.json')
# df = pd.read_json(r'RAW_recipes-entities-final.json')
pd.DataFrame.from_dict(df).head(10)
# df.head()

# 'name': sa.types.VARCHAR,
#               'description': sa.types.TEXT,
#               'nutrition': sa.dialects.postgresql.JSONB,
#               'number_of_steps': sa.types.INTEGER,

df.to_sql('product',
          postgreSQLConnection,
          schema="public",
          if_exists='replace',
        #   index=False,
          index=True,
          dtype={
              # 'index': sa.types.Integer(primary_key=True),
              'code': sa.types.TEXT,
              'url': sa.types.TEXT,
              'creator': sa.types.TEXT,
              'created_t': sa.types.TEXT,
              'created_datetime': sa.types.TEXT,
              'last_modified_t': sa.types.TEXT,
              'last_modified_datetime': sa.types.TEXT,
              'product_name': sa.types.TEXT,
              'generic_name': sa.types.TEXT,
              'quantity': sa.types.TEXT,
              'packaging': sa.types.TEXT,
              'packaging_tags': sa.types.TEXT,
              'packaging_text': sa.types.TEXT,
              'brands': sa.types.TEXT,
              'brands_tags': sa.types.TEXT,
              'categories': sa.types.TEXT,
              'categories_tags': sa.types.TEXT,
              'categories_en': sa.types.TEXT,
              'origins': sa.types.TEXT,
              'origins_tags': sa.types.TEXT,
              'origins_en': sa.types.TEXT,
              'manufacturing_places': sa.types.TEXT,
              'manufacturing_places_tags': sa.types.TEXT,
              'labels': sa.types.TEXT,
              'labels_tags': sa.types.TEXT,
              'labels_en': sa.types.TEXT,
              'emb_codes': sa.types.TEXT,
              'emb_codes_tags': sa.types.TEXT,
              'first_packaging_code_geo': sa.types.TEXT,
              'cities': sa.types.TEXT,
              'cities_tags': sa.types.TEXT,
              'purchase_places': sa.types.TEXT,
              'stores': sa.types.TEXT,
              'countries': sa.types.TEXT,
              'countries_tags': sa.types.TEXT,
              'countries_en': sa.types.TEXT,
              'ingredients_text': sa.types.TEXT,
              'allergens': sa.types.TEXT,
              'allergens_en': sa.types.TEXT,
              'traces': sa.types.TEXT,
              'traces_tags': sa.types.TEXT,
              'traces_en': sa.types.TEXT,
              'serving_size': sa.types.TEXT,
              'serving_quantity': sa.types.TEXT,
              'no_nutriments': sa.types.TEXT,
              'additives_n': sa.types.TEXT,
              'additives': sa.types.TEXT,
              'additives_tags': sa.types.TEXT,
              'additives_en': sa.types.TEXT,
              'ingredients_from_palm_oil_n': sa.types.TEXT,
              'ingredients_from_palm_oil': sa.types.TEXT,
              'ingredients_from_palm_oil_tags': sa.types.TEXT,
              'ingredients_that_may_be_from_palm_oil_n': sa.types.TEXT,
              'ingredients_that_may_be_from_palm_oil': sa.types.TEXT,
              'ingredients_that_may_be_from_palm_oil_tags': sa.types.TEXT,
              'nutriscore_score': sa.types.TEXT,
              'nutriscore_grade': sa.types.TEXT,
              'nova_group': sa.types.TEXT,
              'pnns_groups_1': sa.types.TEXT,
              'pnns_groups_2': sa.types.TEXT,
              'states': sa.types.TEXT,
              'states_tags': sa.types.TEXT,
              'states_en': sa.types.TEXT,
              'brand_owner': sa.types.TEXT,
              'main_category': sa.types.TEXT,
              'main_category_en': sa.types.TEXT,
              'image_url': sa.types.TEXT,
              'image_small_url': sa.types.TEXT,
              'image_ingredients_url': sa.types.TEXT,
              'image_ingredients_small_url': sa.types.TEXT,
              'image_nutrition_url': sa.types.TEXT,
              'energy_kj_100g': sa.dialects.postgresql.FLOAT,
              'energy_kcal_100g': sa.dialects.postgresql.FLOAT,
              'energy_100g': sa.dialects.postgresql.FLOAT,
              'energy_from_fat_100g': sa.dialects.postgresql.FLOAT,
              'fat_100g': sa.dialects.postgresql.FLOAT,
              'saturated_fat_100g': sa.dialects.postgresql.FLOAT,
              '_butyric_acid_100g': sa.dialects.postgresql.FLOAT,
              '_caproic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_caprylic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_capric_acid_100g': sa.dialects.postgresql.FLOAT,
              '_lauric_acid_100g': sa.dialects.postgresql.FLOAT,
              '_myristic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_palmitic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_stearic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_arachidic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_behenic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_lignoceric_acid_100g': sa.dialects.postgresql.FLOAT,
              '_cerotic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_montanic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_melissic_acid_100g': sa.dialects.postgresql.FLOAT,
              'monounsaturated_fat_100g': sa.dialects.postgresql.FLOAT,
              'polyunsaturated_fat_100g': sa.dialects.postgresql.FLOAT,
              'omega_3_fat_100g': sa.dialects.postgresql.FLOAT,
              '_alpha_linolenic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_eicosapentaenoic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_docosahexaenoic_acid_100g': sa.dialects.postgresql.FLOAT,
              'omega_6_fat_100g': sa.dialects.postgresql.FLOAT,
              '_linoleic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_arachidonic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_gamma_linolenic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_dihomo_gamma_linolenic_acid_100g': sa.dialects.postgresql.FLOAT,
              'omega_9_fat_100g': sa.dialects.postgresql.FLOAT,
              '_oleic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_elaidic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_gondoic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_mead_acid_100g': sa.dialects.postgresql.FLOAT,
              '_erucic_acid_100g': sa.dialects.postgresql.FLOAT,
              '_nervonic_acid_100g': sa.dialects.postgresql.FLOAT,
              'trans_fat_100g': sa.dialects.postgresql.FLOAT,
              'cholesterol_100g': sa.dialects.postgresql.FLOAT,
              'carbohydrates_100g': sa.dialects.postgresql.FLOAT,
              'sugars_100g': sa.dialects.postgresql.FLOAT,
              '_sucrose_100g': sa.dialects.postgresql.FLOAT,
              '_glucose_100g': sa.dialects.postgresql.FLOAT,
              '_fructose_100g': sa.dialects.postgresql.FLOAT,
              '_lactose_100g': sa.dialects.postgresql.FLOAT,
              '_maltose_100g': sa.dialects.postgresql.FLOAT,
              '_maltodextrins_100g': sa.dialects.postgresql.FLOAT,
              'starch_100g': sa.dialects.postgresql.FLOAT,
              'polyols_100g': sa.dialects.postgresql.FLOAT,
              'fiber_100g': sa.dialects.postgresql.FLOAT,
              '_soluble_fiber_100g': sa.dialects.postgresql.FLOAT,
              '_insoluble_fiber_100g': sa.dialects.postgresql.FLOAT,
              'proteins_100g': sa.dialects.postgresql.FLOAT,
              'casein_100g': sa.dialects.postgresql.FLOAT,
              'serum_proteins_100g': sa.dialects.postgresql.FLOAT,
              'nucleotides_100g': sa.dialects.postgresql.FLOAT,
              'salt_100g': sa.dialects.postgresql.FLOAT,
              'sodium_100g': sa.dialects.postgresql.FLOAT,
              'alcohol_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_a_100g': sa.dialects.postgresql.FLOAT,
              'beta_carotene_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_d_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_e_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_k_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_c_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_b1_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_b2_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_pp_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_b6_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_b9_100g': sa.dialects.postgresql.FLOAT,
              'folates_100g': sa.dialects.postgresql.FLOAT,
              'vitamin_b12_100g': sa.dialects.postgresql.FLOAT,
              'biotin_100g': sa.dialects.postgresql.FLOAT,
              'pantothenic_acid_100g': sa.dialects.postgresql.FLOAT,
              'silica_100g': sa.dialects.postgresql.FLOAT,
              'bicarbonate_100g': sa.dialects.postgresql.FLOAT,
              'potassium_100g': sa.dialects.postgresql.FLOAT,
              'chloride_100g': sa.dialects.postgresql.FLOAT,
              'calcium_100g': sa.dialects.postgresql.FLOAT,
              'phosphorus_100g': sa.dialects.postgresql.FLOAT,
              'iron_100g': sa.dialects.postgresql.FLOAT,
              'magnesium_100g': sa.dialects.postgresql.FLOAT,
              'zinc_100g': sa.dialects.postgresql.FLOAT,
              'copper_100g': sa.dialects.postgresql.FLOAT,
              'manganese_100g': sa.dialects.postgresql.FLOAT,
              'fluoride_100g': sa.dialects.postgresql.FLOAT,
              'selenium_100g': sa.dialects.postgresql.FLOAT,
              'chromium_100g': sa.dialects.postgresql.FLOAT,
              'molybdenum_100g': sa.dialects.postgresql.FLOAT,
              'iodine_100g': sa.dialects.postgresql.FLOAT,
              'caffeine_100g': sa.dialects.postgresql.FLOAT,
              'taurine_100g': sa.dialects.postgresql.FLOAT,
              'ph_100g': sa.dialects.postgresql.FLOAT,
              'fruits_vegetables_nuts_100g': sa.dialects.postgresql.FLOAT,
              'fruits_vegetables_nuts_dried_100g': sa.dialects.postgresql.FLOAT,
              'fruits_vegetables_nuts_estimate_100g': sa.dialects.postgresql.FLOAT,
              'collagen_meat_protein_ratio_100g': sa.dialects.postgresql.FLOAT,
              'cocoa_100g': sa.dialects.postgresql.FLOAT,
              'chlorophyl_100g': sa.dialects.postgresql.FLOAT,
              'carbon_footprint_100g': sa.dialects.postgresql.FLOAT,
              'carbon_footprint_from_meat_or_fish_100g': sa.dialects.postgresql.FLOAT,
              'nutrition_score_fr_100g': sa.types.TEXT,
              'nutrition_score_uk_100g': sa.types.TEXT,
              'glycemic_index_100g': sa.dialects.postgresql.FLOAT,
              'water_hardness_100g': sa.dialects.postgresql.FLOAT,
              'choline_100g': sa.dialects.postgresql.FLOAT,
              'phylloquinone_100g': sa.dialects.postgresql.FLOAT,
              'beta_glucan_100g': sa.dialects.postgresql.FLOAT,
              'inositol_100g': sa.dialects.postgresql.FLOAT,
              'carnitine_100g': sa.dialects.postgresql.FLOAT
              
          })
            # 'recipe_id': alchemy.types.INTEGER,
            # 'id': alchemy.types.INTEGER,
            # 'updated_by_id': alchemy.types.INTEGER,
            # 'created_by_id': alchemy.types.INTEGER,
            # 'name': alchemy.types.VARCHAR,
            # 'description': alchemy.types.TEXT,
            # 'nutrition': alchemy.dialects.postgresql.JSONB,
            # 'tags': alchemy.dialects.postgresql.JSONB, 
            # 'submitted': alchemy.types.TIMESTAMP,
            # 'number_of_steps': alchemy.types.INTEGER,
            # 'ingredients': alchemy.dialects.postgresql.JSONB,
            # 'steps': alchemy.dialects.postgresql.JSONB, 
            # 'number_of_ingredients': alchemy.types.INTEGER,
            # 'created_at': alchemy.types.DATETIME(timezone=False),
            # 'updated_at': alchemy.types.DATETIME(timezone=False),
            # # 'published_at': alchemy.types.DATETIME(timezone=False),
          

# with engine.connect() as con:
#     con.execute('ALTER TABLE recipes ADD PRIMARY KEY (id);')

# df.head(20)
# CHUNK_SIZE = 5000000 

# dtypes = {'latitude': sa.dialects.postgresql.FLOAT, 'longitude': sa.dialects.postgresql.FLOAT}

# iter_csv = pd.read_csv(
#     filename, iterator=True,
#     # dtype=dtypes,
#      encoding='utf-8', chunksize=CHUNK_SIZE)

# cnt = 0
# for ix, chunk in enumerate(iter_csv):
#     chunk.to_hdf(
#         "en.openfoodfacts.org.products.hdf", 'data', format='table', append=True)
#     cnt += CHUNK_SIZE
#     clear_output(wait=True)
#     print(f"Processed {cnt:,.0f} coordinates..")

# %%
import vaex
import vaex.jupyter.model as vjm

import numpy as np
import matplotlib.pyplot as plt

df = vaex.example()
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3b941da35cf6> in <module>
#       1 import vaex
# ----> 2 import vaex.jupyter.model as vjm
#       3
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/vaex/jupyter/model.py in <module>
#       5 import traitlets
#       6 import numpy as np
# ----> 7 import xarray
#       8
#       9 import vaex
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/xarray/__init__.py in <module>
# ----> 1 from . import testing, tutorial
#       2 from .backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#       5     open_dataarray,
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/xarray/testing.py in <module>
#       7 import pandas as pd
#       8
# ----> 9 from xarray.core import duck_array_ops, formatting, utils
# ...

# %%
import pandas as pd
import json 

df = pd.read_csv (r'RAW_recipes.csv')
df.to_json (r'RAW_recipes-formatted.json')

# run in shell
# cat RAW_recipes-formatted.json | jq > RAW_recipes-formatted.json

# %%
import pandas as pd
import ast

df = pd.read_json(r'RAW_recipes-formatted.json')
df_tags = df[['steps', 'ingredients', 'tags',
              'nutrition']].applymap(lambda x: ast.literal_eval(x))

# df.set_axis([*df.columns,'created_by_id','updated_by_id','recipe_id'],axis=1,inplace=True)

def addId(row):
   return row['id']

df['recipe_id'] = df.apply(addId, axis=1)
df['updated_by_id'] = df.apply(lambda: 1, axis=1)
df['created_by_id'] = df.apply(lambda: 1, axis=1)

df_new = df
df_new[['steps', 'ingredients', 'tags', 'nutrition']] = df_tags
# df_new[['created_by_id','updated_by_id','recipe_id']] = df_ids
df_new.to_json(r'RAW_recipes-arrays-formatted-final.json')
# df_new.to_json(r'RAW_recipes-arrays-formatted.json')

# run in shell
# cat RAW_recipes-arrays-formatted.json | jq > RAW_recipes-arrays-formatted.json
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d3693b03e081> in <module>
#      12
#      13 df['recipe_id'] = df.apply(addId, axis=1)
# ---> 14 df['updated_by_id'] = df.apply(lambda: 1, axis=1)
#      15 df['created_by_id'] = df.apply(lambda: 1, axis=1)
#      16
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ...

# %%
import pandas as pd

df = pd.read_json(r'RAW_recipes-arrays-formatted.json')

def columnTuplesIntoObject(index):
    return dict(list(map(lambda x: [x, df[x][index]], df.columns)))


# print(columnTuplesIntoObject(1))

entities = [columnTuplesIntoObject(index) for index in range(len(df['name']))]

df_entities = pd.DataFrame(data={'data': entities})
df_entities.to_json(r'RAW_recipes-entities-formatted.json')
# run in shell
# cat RAW_recipes-entities.json | jq >[[2022-06-22]]

# %%
import pandas as pd
import json

# df = pd.read_json(r'RAW_recipes-arrays-formatted.json')
df = pd.read_json(r'RAW_recipes-arrays-formatted-final.json')


def columnTuplesIntoObject(index):
    return dict(list(map(lambda x: [x, df[x][index]], df.columns)))


# print(columnTuplesIntoObject(1))

entities = [columnTuplesIntoObject(index) for index in range(len(df['name']))]

dt = pd.DataFrame(data=entities)
records = dt.to_dict('records')
with open('RAW_recipes-entities-final.json', 'w', encoding='utf-8') as f:
    json.dump(records, f, ensure_ascii=False, indent=2)

# run in shell
# cat RAW_recipes-entities.json | jq >[[2022-06-22]]
# Out:
# {'name': 'a bit different  breakfast pizza', 'id': 31490, 'minutes': 30, 'contributor_id': 26278, 'submitted': '2002-06-17', 'tags': ['30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'breakfast', 'main-dish', 'pork', 'american', 'oven', 'easy', 'kid-friendly', 'pizza', 'dietary', 'northeastern-united-states', 'meat', 'equipment'], 'nutrition': [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0], 'n_steps': 9, 'steps': ['preheat oven to 425 degrees f', 'press dough into the bottom and sides of a 12 inch pizza pan', 'bake for 5 minutes until set but not browned', 'cut sausage into small pieces', 'whisk eggs and milk in a bowl until frothy', 'spoon sausage over baked crust and sprinkle with cheese', 'pour egg mixture slowly over sausage and cheese', 's& p to taste', 'bake 15-20 minutes or until eggs are set and crust is brown'], 'description': 'this recipe calls for the crust to be prebaked a bit before adding ingredients. 
# ...

# %%
import pandas as pd
import sqlalchemy as alchemy

engine = alchemy.create_engine(
    'postgresql://strapi:strapi@localhost:5432/strapi')
    # 'postgresql://postgres:example@localhost:5432/strapi')
postgreSQLConnection = engine.connect()

# df = pd.read_json(r'RAW_recipes-arrays-formatted.json')
df = pd.read_json(r'RAW_recipes-entities-final.json')
pd.DataFrame.from_dict(df).head(10)
# df.head()
df.to_sql('recipes',
          postgreSQLConnection,
          schema="public",
          if_exists='replace',
          index=True,
        #   index=False,
          dtype={
            'recipe_id': alchemy.types.INTEGER,
            'id': alchemy.types.INTEGER,
            'updated_by_id': alchemy.types.INTEGER,
            'created_by_id': alchemy.types.INTEGER,
            'name': alchemy.types.VARCHAR,
            'description': alchemy.types.TEXT,
            'nutrition': alchemy.dialects.postgresql.JSONB,
            'tags': alchemy.dialects.postgresql.JSONB, 
            'submitted': alchemy.types.TIMESTAMP,
            'number_of_steps': alchemy.types.INTEGER,
            'ingredients': alchemy.dialects.postgresql.JSONB,
            'steps': alchemy.dialects.postgresql.JSONB, 
            'number_of_ingredients': alchemy.types.INTEGER,
            'created_at': alchemy.types.DATETIME(timezone=False),
            'updated_at': alchemy.types.DATETIME(timezone=False),
            # 'published_at': alchemy.types.DATETIME(timezone=False),
          })

with engine.connect() as con:
    con.execute('ALTER TABLE recipes ADD PRIMARY KEY (id);')

# %%
# change types
import sqlalchemy as alchemy
from alembic import op
cols=['tags', 'ingredients', 'steps']
# connection = op.get_bind()

engine = alchemy.create_engine(
    'postgresql://strapi:strapi@localhost:5432/strapi')
    # 'postgresql://postgres:example@localhost:5432/strapi')
postgreSQLConnection = engine.connect()
alembic_connection = op.get_bind()

for col in cols:

    op.alter_column(
        'recipes', col, existing_type=alchemy.types.ARRAY(alchemy.types.TEXT), type_=alchemy.dialects.postgresql.JSONB, postgresql_using=f"{col}::jsonb"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/alembic/op.py in get_bind(*args, **kw)
#
# NameError: name '_proxy' is not defined
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fd60d4041548> in <module>
#       9     # 'postgresql://postgres:example@localhost:5432/strapi')
#      10 postgreSQLConnection = engine.connect()
# ---> 11 alembic_connection = op.get_bind()
#      12
#      13 for col in cols:
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/alembic/op.py in get_bind(*args, **kw)
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/alembic/util/langhelpers.py in _name_error(name, from_)
#      94
#      95         def _name_error(name, from_):
# ---> 96             raise NameError(
# ...

# %%
import pandas as pd
import sqlalchemy as sa 

engine = sa.create_engine(
    'postgresql://postgres:example@localhost:5432/recipes')
postgreSQLConnection = engine.connect()

df = pd.read_json(r'RAW_recipes-arrays-formatted.json')
pd.DataFrame.from_dict(df).head(10)
# df.head()
df.to_sql('recipe',
          postgreSQLConnection,
          schema="recipe",
          if_exists='replace',
          index=False,
          dtype={
              'name': sa.types.VARCHAR,
              'description': sa.types.TEXT,
              'nutrition': sa.dialects.postgresql.JSONB,
              #sa.types.ARRAY(sa.types.TEXT),
              'tags': sa.dialects.postgresql.JSONB,
                #sa.types.ARRAY(sa.types.TEXT),
              'submitted': sa.types.TIMESTAMP,
              'number_of_steps': sa.types.INTEGER,
              'ingredients': sa.dialects.postgresql.JSONB,
              #sa.types.ARRAY(sa.types.TEXT),

              'steps': sa.dialects.postgresql.JSONB,
              #sa.types.ARRAY(sa.types.TEXT),

              'number_of_ingredients': sa.types.INTEGER,
							'created_at': sa.types.DATETIME(timezone=False),
							'updated_at': sa.types.DATETIME(timezone=False),
							'published_at': sa.types.DATETIME(timezone=False),
          })
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3210         try:
# -> 3211             return fn()
#    3212         except dialect.dbapi.Error as e:
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~/miniconda3/envs/gf/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ...

# %%
import pandas as pd
import json

df = pd.read_json(r'RAW_recipes-arrays-formatted.json')

def columnTuplesIntoObject(index):
    return dict(list(map(lambda x: ['params', {'id':df[x][index]}], df.columns)))


# print(columnTuplesIntoObject(1))

entities = [{'params': {'id':index}} for index in range(len(df['id']))]
# entities = [columnTuplesIntoObject(index) for index in range(len(df['id']))]

dt = pd.DataFrame(data=entities)
records = dt.to_dict('records')
with open('RAW_recipes-ids-final.json', 'w', encoding='utf-8') as f:
    json.dump(records, f, ensure_ascii=False, indent=2)

# %%
import pandas as pd
import sqlalchemy as alchemy

engine = alchemy.create_engine(
    'postgresql://strapi:strapi@localhost:5432/strapi')
    # 'postgresql://postgres:example@localhost:5432/strapi')
postgreSQLConnection = engine.connect()

with engine.connect() as con:
    # con.execute('ALTER TABLE recipes ADD PRIMARY KEY (id);')
		con.execute(
		# ALTER TABLE recipes
		# 		ADD CONSTRAINT recipes_created_by_id_fk foreign key (id) references admin_users (id);
		# '''
		'''
		ALTER TABLE public.recipes DROP COLUMN updated_by_id;
		''')
		# ALTER TABLE recipes
    # ADD CONSTRAINT recipes_created_by_id_fk FOREIGN KEY (created_by_id) REFERENCES admin_users (id);
      # ADD CONSTRAINT fk_author_bookstore FOREIGN KEY (public) 
      #     REFERENCES admin_users (id);
# 		ALTER TABLE recipes
# ADD CONSTRAINT recipes_created_by_id_fk references public;
